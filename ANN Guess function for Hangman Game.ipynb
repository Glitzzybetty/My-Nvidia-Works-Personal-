# %% [markdown]
# <a href="https://colab.research.google.com/github/Glitzzybetty/My-Nvidia-Works-Personal-/blob/main/ANN%20Guess%20function%20for%20Hangman%20Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
import numpy as np
import tensorflow as tf

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []

        full_dictionary_location = "/content/drive/MyDrive/words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()

        self.current_dictionary = []

    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        ###### MY GUESS ALGORITHM BEFORE ############
        #### THE GUESS MODEL FUNCTION (NN with Transformer)
        #### The model is developed and saved as an h5 file below

        # Transformer encoder block
        #def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
            # Multi-head self-attention
         #   x = tf.keras.layers.MultiHeadAttention(
          #      key_dim=head_size, num_heads=num_heads, dropout=dropout
           # )(inputs, inputs)
            #x = tf.keras.layers.Dropout(dropout)(x)
            #x = tf.keras.layers.Add()([x, inputs])
            #x = LayerNormalization(epsilon=1e-6)(x)

            # Feed-forward network
            #x_ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x)
            #x_ff = tf.keras.layers.Dropout(dropout)(x_ff)
            #x_ff = tf.keras.layers.Dense(inputs.shape[-1])(x_ff)
            #x = tf.keras.layers.Add()([x, x_ff])
            #x = LayerNormalization(epsilon=1e-6)(x)
            #return x

        # Build the Transformer model
        #def build_transformer_model(input_dim, max_length, head_size, num_heads, ff_dim, num_layers, num_classes, dropout=0.1):
         #   inputs = Input(shape=(max_length,), dtype=tf.int32)
          #  x = Embedding(input_dim=input_dim, output_dim=128)(inputs)

           # for _ in range(num_layers):
            #    x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

            #x = tf.keras.layers.GlobalAveragePooling1D()(x)
            #x = tf.keras.layers.Dropout(dropout)(x)
            #x = tf.keras.layers.Dense(128, activation="relu")(x)
            #x = tf.keras.layers.Dropout(dropout)(x)
            #outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)

            #model = Model(inputs, outputs)
            #model.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])
            #return model

        # Load and preprocess the word list
        #def load_words(file_path):
         #   with open(file_path, 'r') as f:
          #      words = [line.strip() for line in f.readlines() if line.strip()]
           # return words

        #def encode_words(words, max_length):
         #   char_set = set('abcdefghijklmnopqrstuvwxyz')
          #  char_to_int = {char: i + 1 for i, char in enumerate(char_set)}  # Reserve 0 for padding
           # encoded_words = []
            #for word in words:
             #   encoded = [char_to_int[char] for char in word if char in char_to_int]
              #  if len(encoded) < max_length:
               #     encoded += [0] * (max_length - len(encoded))  # Padding
                #encoded_words.append(encoded[:max_length])
            #return np.array(encoded_words), char_to_int

        # Define parameters and preprocess data
        #word_file = "words_250000_train.txt"
        #words = load_words(word_file)
        #max_word_length = max(len(word) for word in words)
        #X, char_to_int = encode_words(words, max_word_length)
        #y = np.zeros((X.shape[0], len(char_to_int) + 1))  # One-hot encode labels

        # Fill y with next character probabilities
        #for i, word in enumerate(words):
         #   for j in range(len(word) - 1):
          #      y[i, ord(word[j]) - ord('a') + 1] = 1

        # Train-test split
        #X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

        # Build the Transformer model
        #vocab_size = len(char_to_int) + 1
        #model = build_transformer_model(
         #   input_dim=vocab_size,
          #  max_length=max_word_length,
           # head_size=64,
            #num_heads=4,
           # ff_dim=128,
            #num_layers=4,
            #num_classes=vocab_size,
            #dropout=0.2
        #)

        # Callbacks for better training
        #early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
        #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

        # Train the model and collect training history
        #history = model.fit(
         #   X_train, y_train,
          #  validation_data=(X_val, y_val),
           # epochs=50,
            #batch_size=128,
            #callbacks=[early_stopping, reduce_lr]
        #)

        # Predictions for validation set
        #y_pred_val = model.predict(X_val)
        #y_pred_classes_val = np.argmax(y_pred_val, axis=1)
        #y_true_classes_val = np.argmax(y_val, axis=1)

        # Predictions for training set
        #y_pred_train = model.predict(X_train)
        #y_pred_classes_train = np.argmax(y_pred_train, axis=1)
        #y_true_classes_train = np.argmax(y_train, axis=1)

        # Metrics calculation
        #r2_train = r2_score(y_true_classes_train, y_pred_classes_train)
        #r2_val = r2_score(y_true_classes_val, y_pred_classes_val)

        #mse_train = mean_squared_error(y_true_classes_train, y_pred_classes_train)
        #mse_val = mean_squared_error(y_true_classes_val, y_pred_classes_val)

        # Function to print metrics
        #def print_metrics(history, r2_train, r2_val, mse_train, mse_val):
         #   print("Model Performance Metrics:")
          #  print("-" * 40)
           # print(f"Final Training Accuracy: {history.history['accuracy'][-1]:.2%}")
            #print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1]:.2%}")
            #print(f"Final Training Loss: {history.history['loss'][-1]:.4f}")
            #print(f"Final Validation Loss: {history.history['val_loss'][-1]:.4f}")
            #print(f"Training R² Score: {r2_train:.4f}")
            #print(f"Validation R² Score: {r2_val:.4f}")
            #print(f"Training MSE: {mse_train:.4f}")
            #print(f"Validation MSE: {mse_val:.4f}")
            #print("-" * 40)

        # Print metrics
        #print_metrics(history, r2_train, r2_val, mse_train, mse_val)

        # Save the model for use in the Hangman game
        #model.save('hangman_transformer_model.h5')

        self.nn_model = tf.keras.models.load_model('hangman_transformer_model.h5')
        #### The above model is the transformer guess model, save and called as the guess model
        ###############################################

        # Preprocess the word (remove spaces and replace "_" with 0 for NN input)
        clean_word = word[::2]
        encoded_input = [0 if char == '_' else ord(char) - ord('a') + 1 for char in clean_word]

        # Pad the input to the maximum word length expected by the model
        max_word_length = self.nn_model.input_shape[1]
        if len(encoded_input) < max_word_length:
            encoded_input += [0] * (max_word_length - len(encoded_input))

        encoded_input = np.array(encoded_input).reshape(1, -1)

        # Predict the next character using the NN model
        prediction = self.nn_model.predict(encoded_input)
        predicted_char_index = np.argmax(prediction, axis=-1)[0]
        guessed_char = chr(predicted_char_index + ord('a') - 1)

        # Ensure the guessed character hasn't been guessed already
        for letter in string.ascii_lowercase:
            if letter == guessed_char and letter not in self.guessed_letters:
                return letter

        # Fallback to most frequent letter logic if NN fails or all characters guessed
        clean_word = word[::2].replace("_", ".")
        len_word = len(clean_word)

        current_dictionary = self.current_dictionary
        new_dictionary = []

        for dict_word in current_dictionary:
            if len(dict_word) != len_word:
                continue

            if re.match(clean_word, dict_word):
                new_dictionary.append(dict_word)

        self.current_dictionary = new_dictionary

        full_dict_string = "".join(new_dictionary)
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()

        guess_letter = '!'

        for letter, instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                guess_letter = letter
                break

        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter, instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break

        return guess_letter

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################

    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary

    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary

        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print(f"Game ID: {game_id}, Tries Remaining: {tries_remains}, Initial Word: {word}")
            while tries_remains > 0:
                # get guessed letter from user code
                guess_letter = self.guess(word)

                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print(f"Guessing Letter: {guess_letter}, Current Word: {word}")

                try:
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print(f"HangmanAPIError: Error on Game ID: {game_id}.")
                    continue
                except Exception as e:
                    print(f"Exception Caught: {e}")
                    raise e

                if verbose:
                    print(f"Server Response: {res}")
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                word = res.get('word')

                if status == "success":
                    if verbose:
                        print(f"Game ID {game_id}: Successfully Completed! Final Word: {word}")
                    return True
                elif status == "failed":
                    if verbose:
                        print(f"Game ID {game_id}: Failed. Tries Remaining: {tries_remains}, Final Word: {word}")
                    return False
        else:
            if verbose:
                print("Failed to start a new game")
        return status == "success"

    def my_status(self):
        return self.request("/my_status", {})

    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.5)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result

class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %%
# Initialize the HangmanAPI and play 1000 games
api = HangmanAPI(access_token="0bcbf66d0fa17a721f28778ff67195", timeout=2000)

num_games = 1000
games_won = 0
games_lost = 0

for game in range(num_games):
    print(f"Starting Game {game + 1}...")
    result = api.start_game(practice=0, verbose=False)
    if result:
        games_won += 1
        print(f"Game {game + 1}: WON")
    else:
        games_lost += 1
        print(f"Game {game + 1}: LOST")

print("\nSummary of 1000 Games:")
print(f"Games Won: {games_won}")
print(f"Games Lost: {games_lost}")

# Calculate and print success rate for current games played
if num_games > 0:
    current_game_success_rate = (games_won / num_games) * 100
    print(f"Current Game Success Rate: {current_game_success_rate:.2f}%")
else:
    print("No games played in the current session.")

# Retrieve and calculate overall practice game statistics
[total_practice_runs, total_recorded_runs, total_recorded_successes, total_practice_successes] = api.my_status()
if total_practice_runs > 0:
    practice_success_rate = (total_practice_successes / total_practice_runs) * 100
    practice_loss_rate = 100 - practice_success_rate
    print(f"Total Practice Games Played: {total_practice_runs}")
    print(f"Practice Game Success Rate: {practice_success_rate:.2f}%")
    print(f"Practice Game Loss Rate: {practice_loss_rate:.2f}%")
else:
    print("No practice games recorded.")

# Calculate overall recorded success rate
if total_recorded_runs > 0:
    overall_success_rate = (total_recorded_successes / total_recorded_runs) * 100
    print(f"Overall Success Rate (Recorded Games): {overall_success_rate:.2f}%")
else:
    print("No recorded games available.")
# Out:
# Starting Game 1...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 886ms/step
# ...

# %%
print("\nSummary of 1000 Games:")
print(f"Games Won: {games_won}")
print(f"Games Lost: {games_lost}")

# Calculate and print success rate for current games played
if num_games > 0:
    current_game_success_rate = (games_won / num_games) * 100
    print(f"Current Game Success Rate: {current_game_success_rate:.2f}%")
else:
    print("No games played in the current session.")

# Retrieve and calculate overall practice game statistics
[total_practice_runs, total_recorded_runs, total_recorded_successes, total_practice_successes] = api.my_status()
if total_practice_runs > 0:
    practice_success_rate = (total_practice_successes / total_practice_runs) * 100
    practice_loss_rate = 100 - practice_success_rate
    print(f"Total Practice Games Played: {total_practice_runs}")
    print(f"Practice Game Success Rate: {practice_success_rate:.2f}%")
    print(f"Practice Game Loss Rate: {practice_loss_rate:.2f}%")
else:
    print("No practice games recorded.")

# Calculate overall recorded success rate
if total_recorded_runs > 0:
    overall_success_rate = (total_recorded_successes / total_recorded_runs) * 100
    print(f"Overall Success Rate (Recorded Games): {overall_success_rate:.2f}%")
else:
    print("No recorded games available.")
# Out:
# Summary of 1000 Games:
# Games Won: 48
# Games Lost: 198
# Current Game Success Rate: 4.80%
# Total Practice Games Played: 16914
# Practice Game Success Rate: 18.13%
# Practice Game Loss Rate: 81.87%
# Overall Success Rate (Recorded Games): 18.90%
